# %% [markdown]
# # Analysis: Monday Coffee Co. Market Potential in India

# %% [markdown]
# ## Overview
#
# The business aims to expand by opening three coffee shops in India's top three major cities. Since its launch in January 2023, the company has successfully sold it's products online and received overwhelmingly positive response in several cities.

# %% [markdown]
# ### Main Goal
#
# The goal of the project is to analyze [data (includes link to source of data)](https://www.kaggle.com/datasets/najir0123/monday-coffee-sql-data-analysis-project/) from India focus on market potential for the Monday Coffee Company and recommend the top three major cities for opening new coffee shops locations based on consumer demand and sales performance.

# %% [markdown]
# ### Questions that lead us to solutions:
#
# #### What cities have:
#
# 1. highest **revenue**?
#
# 2. highest **sales**?
#
# 3. lowest **costs of rent**?
#
# 4. highest **number of unique customers**?
#
# 5. highest **estimate coffee consumers**?
#
# #### 6. What are the **Top 3 Cities** for opening new coffee stores locations?

# %% [markdown]
# ### Tools I Used:
#
# - **PostgreSQL**: Stores data and Queries, analyzing the data.
# - **Visual Studio Code**: To connect with database, writing queries in 'SQL file'.
# - **Power Bi**: Visualizing the data.
# - **Jupyter Notebook**: Create project interactive document.

# %% [markdown]
# ### Create tables and load data:

# %% [markdown]
# #### 1. Step:

# %% [markdown]
# City table:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Customers table:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sales table:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2. Step:
#
# #### Import manually data from 'csv files' to our tables.

# %% [markdown]
# #### 3. Overview Data:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# Result sample:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Result sample:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Result sample:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Checking num of rows:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### Checking missing values:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Results:

# %% [markdown]
# We have 0 missing values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Checking duplicates:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Results:

# %% [markdown]
# Result shows us that we have 0 duplicates.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Queries and Analysis:

# %% [markdown]
# ### 1. Total revenue generated from coffee sales across all cities:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Result:
#
# ##### Top 5 Cities:
#
# ##### 1. Pune: $ 1258290.
#
# ##### 2. Chennai $ 944120.
#
# ##### 3. Bangalore: $ 860110.
#
# ##### 4. Jaipur: $ 803450.
#
# ##### 5. Delhi: $ 750420.
#
# ##### - How we see, **Pune** is first and there are significiant differences between it and the other cities.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Avg sales amount per customer in each city:

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### Result:
#
# #### Top 5 Cities with the highest Avg Sale:
#
# ##### 1. Pune: $ 24197.88
# #####
# ##### 2. Chennai: $ 22479.05
# #####
# ##### 3. Bangalore: $ 22054.10
# #####
# ##### 4. Jaipur: $ 11644.20
# #####
# ##### 5. Delhi: $ 11035.59
#
# ##### - We can notice that cities with the highest revenue and average sales, do not always have a higher number of customers than others.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Each city and their average rent per customer:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Result:
#
# #### Top 5 Cities with the lowest Avg Rent:
#
# ##### 1. Jaipur: $ 156.52
# #####
# ##### 2. Kanpur: $ 231.43
# #####
# ##### 3. Pune: $ 294.23
# #####
# ##### 4. Indore: $ 300.00
# #####
# ##### 5. Nagpur: $ 300.00
#
# ##### - We see that **Delhi** and **Pune** have higher population and costs of rent per customer are relatively low, what is worth to considering from the perspective of cost optimization.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 4. Number of unique customers there are in each city who have purchased coffee products:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Result:
#
# #### Top 3 Cities by number of Customers:
#
# ##### 1. Jaipur: 69 unique customers.
#
# ##### 2. Delhi: 68 unique customers.
#
# ##### 3. Pune: 52 unique customers.
#
# ##### - In first place, we have the **Jaipur** city, which also has one of the lowest populations. This may be due to less competition.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5. Number of people in each city are estimated to consume coffee, given that 25% of the population:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Result:
#
# #### Top 3 Cities by estimated Consumers:
#
# ##### 1. Delhi: 7.75 millions.
#
# ##### 2. Mumbai: 5.10 millions.
#
# ##### 3. Kolkata: 3.73 millions.
#
# ##### - **Delhi** has the highest number estimated consumers and customers either.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6. Identifing top 3 city based on highest sales, city name, total sale, total rent, total customers and estimated coffee consumer:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Result:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Visualization Data with using Power BI:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Recommendations:

# %% [markdown]
# #### The recommended Top 3 Cities for new store openings are:
#
# 1. **Pune**
#
# - Average rent per customer is very low.
#
# - The Pune has the highest total revenue.
#
# - Average sales per customer is high as well.
#
# 2. **Delhi**
#
# - The highest estimated consumers are about 7.7 millions.
#
# - Second highest number of customers equal to 68.
#
# - Also rent per customer is very low $ 330.
#
# 3. **Jaipur**
#
# - This city has the highest number of customers (69).
#
# - The lowest rent per customer is equal $ 156.
#
# - Average sale per customer is 11.6K.

# %% [markdown]
# I think that **Chennai** is worth to consider it.
#
# - Second city with the highest revenue, equal $ 944120.
#
# - Sale per customer about $ 22500.
#
# - Cost of rent is relatively low ($ 400).
#
# - *In order to make the right decision*:
#
#     - *it is certainly important to check what kind of competition company face in this city,*
#
#     - *then prepare a suitable offer to attract consumers and*
#
#     - *focus on the right promotional strategy to increase the reach of potential customers.*
